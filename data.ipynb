# %%
from datafetcher import EliaTotalLoadForecastFetcher, EliaWindFetcher, EliaSolarFetcher, ElexysBelpexFetcher
import datetime as dt

# %%
# the first time you use a DataFetcher sub class, it will download some cached data from Dropbox (around 20MB)
# this might take a while depending on your connection speed
df_solar = EliaSolarFetcher().fetch()
df_solar.head()
#df_solar.DayAheadForecast[df_solar.index > dt.datetime.now()-dt.timedelta(weeks=1)].plot()
# Out:
#                      DayAheadForecast  LoadFactor  MonitoredCapacity  \
# 2013-12-31 23:00:00               0.0         0.0            2915.88
# 2013-12-31 23:15:00               0.0         0.0            2915.88
# 2013-12-31 23:30:00               0.0         0.0            2915.88
# 2013-12-31 23:45:00               0.0         0.0            2915.88
# 2014-01-01 00:00:00               0.0         0.0            2915.88
#
#                      MostRecentForecast  WeekAheadForecast
# 2013-12-31 23:00:00                 0.0                NaN
# 2013-12-31 23:15:00                 0.0                NaN
# 2013-12-31 23:30:00                 0.0                NaN
# 2013-12-31 23:45:00                 0.0                NaN
# 2014-01-01 00:00:00                 0.0                NaN

# %%
df_load = EliaTotalLoadForecastFetcher().fetch()
df_load.head()
# Out:
#                        value
# 2014-08-08 08:00:00  8951.13
# 2014-08-08 08:15:00  8929.77
# 2014-08-08 08:30:00  8967.10
# 2014-08-08 08:45:00  8949.09
# 2014-08-08 09:00:00  8734.89

# %%
df_belpex = ElexysBelpexFetcher().fetch()
df_belpex.head()
# Out:
#                      price
# 2018-03-17 23:00:00  52.53
# 2018-03-17 22:00:00  57.89
# 2018-03-17 21:00:00  57.40
# 2018-03-17 20:00:00  63.83
# 2018-03-17 19:00:00  73.61

# %%
# the Elia Wind API is extremely slow, so in this example we only use cached data
df_wind = EliaWindFetcher(only_cached=True).fetch()
df_wind.head()
# Out:
#                      DayAheadConfidence10  DayAheadConfidence90  \
# 2013-12-31 23:00:00                   NaN                   NaN
# 2013-12-31 23:15:00                   NaN                   NaN
# 2013-12-31 23:30:00                   NaN                   NaN
# 2013-12-31 23:45:00                   NaN                   NaN
# 2014-01-01 00:00:00                   NaN                   NaN
#
#                      DayAheadForecast  LoadFactor  MonitoredCapacity  \
# 2013-12-31 23:00:00               NaN        0.52             1487.2
# 2013-12-31 23:15:00               NaN        0.53             1487.2
# 2013-12-31 23:30:00               NaN        0.53             1487.2
# 2013-12-31 23:45:00               NaN        0.55             1487.2
# 2014-01-01 00:00:00               NaN        0.55             1487.2
#
#                      MostRecentForecast  Realtime  WeekAheadConfidence10  \
# 2013-12-31 23:00:00              637.53    780.10                    NaN
# 2013-12-31 23:15:00              629.69    781.09                    NaN
# 2013-12-31 23:30:00              621.87    793.82                    NaN
# 2013-12-31 23:45:00              614.06    824.23                    NaN
# 2014-01-01 00:00:00              606.28    818.43                    NaN
#
#                      WeekAheadConfidence90
# 2013-12-31 23:00:00                    NaN
# 2013-12-31 23:15:00                    NaN
# 2013-12-31 23:30:00                    NaN
# 2013-12-31 23:45:00                    NaN
# 2014-01-01 00:00:00                    NaN
